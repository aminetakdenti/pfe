# %% [markdown]
# # DQN Agent

# %% [markdown]
# ## Imports

# %%
# %pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os
import random

# %% [markdown]
# ## DataLoader

# %%
TRANING_DATA = 0.8
BATCH_SIZE = 64

class DataLoader:
    def __init__(self, csv_path, batch_size):
        self.df_samples = pd.read_csv(csv_path)

        self.features = self.df_samples[-1:].keys()
        print(self.features)
        self.states_features = self.df_samples.iloc[:, 1:-1]
        self.features_dim = self.states_features.shape[1]
        self.actions_labels = self.df_samples.iloc[:, -1]
        self.actions_classes = self.actions_labels.unique()
        self.actions_set = set(self.actions_classes)
        self.prepare_batches(batch_size, TRANING_DATA)

    def prepare_batches(self, batch_size, train_split_percent):
        states_t = self.states_features.iloc[:-1, :].copy()
        states_t_plus_one = self.states_features.iloc[1:, :].copy()
        actions_t = self.actions_labels[:-1].copy()

        print(f"state_t: {states_t.shape}")
        print(f"state_t+1: {states_t_plus_one.shape}")
        print(f"action_t: {actions_t.shape}", self.actions_labels)

csv_path = os.path.join(os.getcwd(), "src", "data", "ids_data.csv")
df = DataLoader(csv_path, BATCH_SIZE)
# Out:
# Index(['id', 'command_address', 'response_address', 'command_memory',
#        'response_memory', 'command_memory_count', 'response_memory_count',
#        'comm_read_function', 'comm_write_fun', 'resp_read_fun',
#        'resp_write_fun', 'sub_function', 'command_length', 'resp_length',
#        'gain', 'reset', 'deadband', 'cycletime', 'rate', 'setpoint',
#        'control_mode', 'control_scheme', 'pump', 'solenoid', 'crc_rate',
#        'measurement', 'time', 'result'],
#       dtype='object')
# state_t: (97018, 26)
# state_t+1: (97018, 26)
# action_t: (97018,) 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 97014    0
# 97015    0
# 97016    0
# 97017    0
# 97018    0
# Name: result, Length: 97019, dtype: int64
